# %%
# Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Import our data into pandas from CSV
string_thing = '../Data/trip.csv'
bike_trips_df = pd.read_csv(string_thing, low_memory=False)

bike_trips_df
# Out:
#                 stoptime    bikeid  tripduration  \
# 0       10/13/2014 10:48  SEA00298       985.935
# 1       10/13/2014 10:48  SEA00195       926.375
# 2       10/13/2014 10:48  SEA00486       883.831
# 3       10/13/2014 10:48  SEA00333       865.937
# 4       10/13/2014 10:49  SEA00202       923.923
# 5       10/13/2014 10:47  SEA00337       808.805
# 6       10/13/2014 11:45  SEA00202       596.715
# 7       10/13/2014 11:45  SEA00311       592.131
# 8       10/13/2014 11:45  SEA00486       586.347
# 9       10/13/2014 11:45  SEA00434       587.634
# 10      10/13/2014 11:45  SEA00195       564.899
# 11      10/13/2014 11:47  SEA00101       620.141
# 12      10/13/2014 11:47  SEA00461       634.087
# 13      10/13/2014 11:47  SEA00044       614.336
# 14      10/13/2014 11:47  SEA00298       601.463
# 15      10/13/2014 11:47  SEA00106       618.781
# 16      10/13/2014 11:47  SEA00108       617.085
# 17      10/13/2014 11:47  SEA00236       600.050
# ...

# %%
# Split up our data into groups based upon 'gender'
gender_groups = bike_trips_df.groupby('gender')

# Find out how many of each gender took bike trips
gender_trips = gender_groups['tripduration'].count()
gender_trips
# Out:
# gender
# Female       37562
# Male        140564
# Other         3431
# stoptime         1
# Name: tripduration, dtype: int64

# %%
# Drop the 'stoptime' row that is contained within our group
gender_trips = gender_trips.drop("stoptime")

# Chart our data, give it a title, and label the axes
gender_chart = gender_trips.plot(kind="bar", title="Bike Trips by Gender")
gender_chart.set_xlabel("Gender")
gender_chart.set_ylabel("Number of Trips Taken")

plt.show()

# %%
# Filter original dataframe to only show rows where "bikeid" column is equal to SEA00001
bikeid = "SEA00001"
one_bike_df = bike_trips_df.loc[bike_trips_df["bikeid"] == bikeid]
one_bike_df.head()
# Out:
#                 stoptime    bikeid  tripduration  \
# 193430  10/12/2015 12:53  SEA00001       213.007
# 193607  10/12/2015 18:50  SEA00001       469.153
# 193953  10/13/2015 17:22  SEA00001       373.126
# 194165   10/14/2015 9:37  SEA00001       316.803
# 194448   10/15/2015 7:59  SEA00001       771.069
#
#                           from_station_name          to_station_name  \
# 193430               6th Ave & Blanchard St   Westlake Ave & 6th Ave
# 193607               Westlake Ave & 6th Ave  Dexter Ave N & Aloha St
# 193953              Dexter Ave N & Aloha St   Westlake Ave & 6th Ave
# 194165               12th Ave & E Denny Way        Pine St & 9th Ave
# 194448  Key Arena / 1st Ave N & Harrison St   6th Ave & Blanchard St
#
#        from_station_id to_station_id usertype  gender birthyear
# 193430           BT-04        SLU-15   Member    Male      1953
# 193607          SLU-15        SLU-02   Member    Male      1988
# ...

# %%
# Group by gender
grouped_bike = one_bike_df.groupby("gender")

# Sum by gender grouping
sum_it_up = grouped_bike.sum()

# Returns a dataframe with 1 column
sum_it_up
# Out:
#         tripduration
# gender
# Female     15876.665
# Male       41150.373
# Other        276.880

# %%
# Create a pie chart based upon the trip duration of that single bike
bike_pie = sum_it_up.plot(kind="pie", y="tripduration", title=("Trips of " + bikeid))

plt.show()
