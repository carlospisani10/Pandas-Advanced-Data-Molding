# %%
import pandas as pd
import numpy

# %%
#import csv
fifapath = "Resources/Soccer2018Data.csv"
fifa_pd = pd.read_csv(fifapath)
fifa_pd.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0  Cristiano Ronaldo   32    Portugal       94         94
# 1           L. Messi   30   Argentina       93         93
# 2             Neymar   25      Brazil       92         94
# 3          L. Suárez   30     Uruguay       92         92
# 4           M. Neuer   31     Germany       92         92
#
#                   Club Preferred Position   CAM    CB   CDM  ...     RB   RCB  \
# 0       Real Madrid CF                 ST  89.0  53.0  62.0  ...   61.0  53.0
# 1         FC Barcelona                 RW  92.0  45.0  59.0  ...   57.0  45.0
# 2  Paris Saint-Germain                 LW  88.0  46.0  59.0  ...   59.0  46.0
# 3         FC Barcelona                 ST  87.0  58.0  65.0  ...   64.0  58.0
# 4     FC Bayern Munich                 GK   NaN   NaN   NaN  ...    NaN   NaN
#
#     RCM   RDM    RF    RM    RS    RW   RWB    ST
# 0  82.0  62.0  91.0  89.0  92.0  91.0  66.0  92.0
# ...

# %%
fifa_players = fifa_pd[["Name", "Overall", "Preferred Position"]]
fifa_players.head()
# Out:
#                 Name  Overall Preferred Position
# 0  Cristiano Ronaldo       94                 ST
# 1           L. Messi       93                 RW
# 2             Neymar       92                 LW
# 3          L. Suárez       92                 ST
# 4           M. Neuer       92                 GK

# %%
fifa_position = fifa_players.groupby(["Preferred Position"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-8619443ccd12> in <module>()
# ----> 1 fifa_position = fifa_players.groupby(["Preffered Position"])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    4414         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    4415                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 4416                        **kwargs)
#    4417
#    4418     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby.py in groupby(obj, by, **kwds)
#    1697         raise TypeError('invalid type: %s' % type(obj))
#    1698
# -> 1699     return klass(obj, by, **kwds)
#    1700
#    1701
#
# ...
