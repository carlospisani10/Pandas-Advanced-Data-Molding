# %%
import pandas as pd
import numpy

# %%
#import csv
fifapath = "Resources/Soccer2018Data.csv"
fifa_pd = pd.read_csv(fifapath)
fifa_pd.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0  Cristiano Ronaldo   32    Portugal       94         94
# 1           L. Messi   30   Argentina       93         93
# 2             Neymar   25      Brazil       92         94
# 3          L. Suárez   30     Uruguay       92         92
# 4           M. Neuer   31     Germany       92         92
#
#                   Club Preferred Position   CAM    CB   CDM  ...     RB   RCB  \
# 0       Real Madrid CF                 ST  89.0  53.0  62.0  ...   61.0  53.0
# 1         FC Barcelona                 RW  92.0  45.0  59.0  ...   57.0  45.0
# 2  Paris Saint-Germain                 LW  88.0  46.0  59.0  ...   59.0  46.0
# 3         FC Barcelona                 ST  87.0  58.0  65.0  ...   64.0  58.0
# 4     FC Bayern Munich                 GK   NaN   NaN   NaN  ...    NaN   NaN
#
#     RCM   RDM    RF    RM    RS    RW   RWB    ST
# 0  82.0  62.0  91.0  89.0  92.0  91.0  66.0  92.0
# 1  84.0  59.0  92.0  90.0  88.0  91.0  62.0  88.0
# 2  79.0  59.0  88.0  87.0  84.0  89.0  64.0  84.0
# 3  80.0  65.0  88.0  85.0  88.0  87.0  68.0  88.0
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 33 columns]

# %%
#collect a list
soccer_2o18_df["Preferred Position'].unique()
# Out:
#   File "<ipython-input-13-6feb2a91d30c>", line 2
#     soccer_2o18_df["Preferred Position'].unique()
#                                                  ^
# SyntaxError: EOL while scanning string literal

# %%
fifa_position = fifa_players.groupby(["Preferred Position"])
fifa_position.head()
# Out:
#                        Name  Overall Preferred Position
# 0         Cristiano Ronaldo       94                 ST
# 1                  L. Messi       93                 RW
# 2                    Neymar       92                 LW
# 3                 L. Suárez       92                 ST
# 4                  M. Neuer       92                 GK
# 5            R. Lewandowski       91                 ST
# 6                    De Gea       90                 GK
# 7                 E. Hazard       90                 LW
# 8                  T. Kroos       90                CDM
# 9                G. Higuaín       90                 ST
# 10             Sergio Ramos       90                 CB
# 11             K. De Bruyne       89                 RM
# 12              T. Courtois       89                 GK
# 13               A. Sánchez       89                 RM
# 14                L. Modrić       89                CDM
# 15                  G. Bale       89                 RW
# 16                S. Agüero       89                 ST
# 17             G. Chiellini       89                 CB
# 18                G. Buffon       89                 GK
# 20                 J. Oblak       88                 GK
# 21             A. Griezmann       88                 LW
# 22                   Thiago       88                CDM
# 24               L. Bonucci       88                 CB
# 25               J. Boateng       88                 CB
# 26                 D. Godín       88                 CB
# 28                  M. Özil       88                 RW
# 32                A. Robben       88                 RW
# 33                 N. Kanté       87                 CM
# 34              M. Verratti       87                CDM
# 35                 P. Pogba       87                CDM
# ...                     ...      ...                ...
# 66                F. Ribéry       86                 LW
# 69              Y. Carrasco       85                 RM
# 80               Jordi Alba       85                 LB
# 82              Azpilicueta       85                 LB
# 89              Filipe Luís       85                 LB
# 94           Bernardo Silva       84                 RM
# 98                 Carvajal       84                 RB
# 112              I. Perišić       84                CAM
# 114                 Willian       84                CAM
# 124              Dani Alves       84                 RB
# 137                M. Salah       83                 RW
# 158               S. Kagawa       83                 CF
# 161               K. Walker       83                RWB
# 177                   Jonas       83                 CF
# 181             A. Valencia       83                 RB
# 184            Borja Valero       83                 CF
# 187                Juanfran       83                 RB
# 217              F. Vázquez       82                 CF
# 221              A. Rüdiger       82                 RB
# 233                 M. Rojo       82                 LB
# 279                 D. Rose       82                LWB
# 362              D. Perotti       81                 CF
# 431   A. Oxlade-Chamberlain       80                RWB
# 449              M. Antonio       80                RWB
# 751               B. Davies       78                LWB
# 756                B. Mendy       78                LWB
# 892              J. Holebas       78                LWB
# 907             K. Trippier       78                RWB
# 1205             D. Janmaat       77                RWB
# 1481           A. Cresswell       76                LWB
#
# [75 rows x 3 columns]
